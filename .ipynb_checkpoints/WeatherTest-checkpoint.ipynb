# %%
# import dependencies
import random # random to generate random latitude and longitudes
import pandas as pd # pandas library
import time 
import seaborn as sns # seaborn library to set the aesthetics for the graphs
import matplotlib.pyplot as plt # for creating/plotting graphs
import numpy as np
from datetime import datetime
import openweathermapy as owm
import csv

# %%
# citypy library - to Look up for city names with geo-coordinates
from citipy import citipy 
cities = []

while len(cities)<600:
    x = (random.choice(range(-90,90))) # randomly generate numbers in range -90 & 90 for latitude
    y = (random.choice(range(-180,180))) # randomly generagte numbers in range -180 & 180 for longitude
    city = citipy.nearest_city(x,y).city_name # look up city to match the lat & long randomly generated
    if city not in cities:
        cities.append(city)

# %%
len(cities)
# Out:
# 600

# %%
# import API Key from config file
from config import weather_key
# Create settings dictionary with information we're interested in
settings = {"units": "imperial", "appid": weather_key}

# Initialize data frame to store data from API calls
WeatherPy_df =pd.DataFrame(columns = ["City","Cloudiness", "Country",
                                    "Date", "Max Temp", "Wind Speed", 
                                    "Lat","Lng", "Humidity"])

# %%
count = 1 # counter to count the number of calls to API
err = 0 # error count to record how many cities the API responds back with no data.
sets = 0 # counter to count the number of call sets
index = 0 # index for the data frame WeatherPy data frame
#Get current time
t0 =time.time()
print(f'Beginning Data Retrieval \n ........................')
for city in cities:
    try:
        city1 = city.replace(" ", "%20") # remove space in city name so the URL retrieved is not broken.
        print(f'Processing Record {count} of Set {sets} | {city}' )
        print(f'{owm.BASE_URL}weather?q={city1}&units=imperial&APPID={weather_key}')
        city_stats = owm.get_current(city, **settings)
        WeatherPy_df.set_value(index, "City", city_stats["name"])
        WeatherPy_df.set_value(index, "Cloudiness", city_stats("clouds.all"))
        WeatherPy_df.set_value(index, "Country", city_stats("sys.country"))
        WeatherPy_df.set_value(index, "Date", city_stats("dt"))
        WeatherPy_df.set_value(index, "Max Temp", city_stats("main.temp_max"))
        WeatherPy_df.set_value(index, "Wind Speed", city_stats("wind.speed"))
        WeatherPy_df.set_value(index, "Lat", city_stats("coord.lat"))
        WeatherPy_df.set_value(index, "Lng", city_stats("coord.lon"))
        WeatherPy_df.set_value(index, "Humidity", city_stats("main.humidity"))
        index = index +1 
    except Exception as e:
        print(e)
        err= err+1
    count = count+1
    if count == 51: # loop to limit 50 API calls per minute. The OpenWeatherMap API limit is 60 calls/min
        t1=time.time()
        count = 1 
        sets = sets+1
        time.sleep(60-(t1-t0))
        t0=time.time()

print("end of stats loop")
print(f'Could not get data for {err} cities')
# Out:
# Beginning Data Retrieval
#  ........................
# Processing Record 1 of Set 0 | cape town
# http://api.openweathermap.org/data/2.5/weather?q=cape%20town&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 0 | najran
# http://api.openweathermap.org/data/2.5/weather?q=najran&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:15: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   from ipykernel import kernelapp as app
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:16: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
#   app.launch_new_instance()
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:17: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:18: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:19: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:20: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# C:\Users\dimpa\Anaconda3\lib\site-packages\ipykernel_launcher.py:22: FutureWarning: set_value is deprecated and will be removed in a future release. Please use .at[] or .iat[] accessors instead
# Processing Record 3 of Set 0 | fukue
# http://api.openweathermap.org/data/2.5/weather?q=fukue&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 0 | busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 0 | bluff
# http://api.openweathermap.org/data/2.5/weather?q=bluff&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 0 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 0 | port alfred
# http://api.openweathermap.org/data/2.5/weather?q=port%20alfred&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 0 | hobart
# http://api.openweathermap.org/data/2.5/weather?q=hobart&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 0 | kahului
# http://api.openweathermap.org/data/2.5/weather?q=kahului&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 0 | rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 0 | kultuk
# http://api.openweathermap.org/data/2.5/weather?q=kultuk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 0 | jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 0 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?q=new%20norfolk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 0 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous%20virieux&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 0 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 0 | leca da palmeira
# http://api.openweathermap.org/data/2.5/weather?q=leca%20da%20palmeira&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 0 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 0 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?q=severo-yeniseyskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 0 | kruisfontein
# http://api.openweathermap.org/data/2.5/weather?q=kruisfontein&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 0 | tabiauea
# http://api.openweathermap.org/data/2.5/weather?q=tabiauea&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 21 of Set 0 | margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 0 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 0 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20ayora&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 0 | eureka
# http://api.openweathermap.org/data/2.5/weather?q=eureka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 0 | olinda
# http://api.openweathermap.org/data/2.5/weather?q=olinda&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 0 | grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 0 | tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 0 | bjala
# http://api.openweathermap.org/data/2.5/weather?q=bjala&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 29 of Set 0 | anadyr
# http://api.openweathermap.org/data/2.5/weather?q=anadyr&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 0 | airai
# http://api.openweathermap.org/data/2.5/weather?q=airai&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 0 | sabzevar
# http://api.openweathermap.org/data/2.5/weather?q=sabzevar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 0 | taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 33 of Set 0 | kichmengskiy gorodok
# http://api.openweathermap.org/data/2.5/weather?q=kichmengskiy%20gorodok&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 0 | illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 35 of Set 0 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?q=nikolskoye&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 0 | pingzhuang
# http://api.openweathermap.org/data/2.5/weather?q=pingzhuang&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 37 of Set 0 | pevek
# http://api.openweathermap.org/data/2.5/weather?q=pevek&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 0 | dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 0 | leh
# http://api.openweathermap.org/data/2.5/weather?q=leh&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 0 | kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=kurilsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 0 | bolungarvik
# http://api.openweathermap.org/data/2.5/weather?q=bolungarvik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 42 of Set 0 | vaini
# http://api.openweathermap.org/data/2.5/weather?q=vaini&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 0 | plettenberg bay
# http://api.openweathermap.org/data/2.5/weather?q=plettenberg%20bay&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 0 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?q=praia%20da%20vitoria&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 of Set 0 | rio gallegos
# http://api.openweathermap.org/data/2.5/weather?q=rio%20gallegos&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 0 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 0 | barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 48 of Set 0 | konstancin-jeziorna
# http://api.openweathermap.org/data/2.5/weather?q=konstancin-jeziorna&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 0 | saleaula
# http://api.openweathermap.org/data/2.5/weather?q=saleaula&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 50 of Set 0 | arlit
# http://api.openweathermap.org/data/2.5/weather?q=arlit&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 1 of Set 1 | pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 1 | fortuna
# http://api.openweathermap.org/data/2.5/weather?q=fortuna&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 1 | pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 1 | samana
# http://api.openweathermap.org/data/2.5/weather?q=samana&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 1 | barrow
# http://api.openweathermap.org/data/2.5/weather?q=barrow&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 1 | cherskiy
# http://api.openweathermap.org/data/2.5/weather?q=cherskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 1 | cumaribo
# http://api.openweathermap.org/data/2.5/weather?q=cumaribo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 8 of Set 1 | botshabelo
# http://api.openweathermap.org/data/2.5/weather?q=botshabelo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 1 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?q=kaitangata&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 1 | geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 1 | torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 1 | luang prabang
# http://api.openweathermap.org/data/2.5/weather?q=luang%20prabang&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 1 | lompoc
# http://api.openweathermap.org/data/2.5/weather?q=lompoc&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 1 | narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 1 | lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 1 | namibe
# http://api.openweathermap.org/data/2.5/weather?q=namibe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 1 | navoi
# http://api.openweathermap.org/data/2.5/weather?q=navoi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 1 | faanui
# http://api.openweathermap.org/data/2.5/weather?q=faanui&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 1 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?q=longyearbyen&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 1 | albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 1 | kingman
# http://api.openweathermap.org/data/2.5/weather?q=kingman&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 1 | predivinsk
# http://api.openweathermap.org/data/2.5/weather?q=predivinsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 1 | amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 24 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?q=bethel&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 1 | pauri
# http://api.openweathermap.org/data/2.5/weather?q=pauri&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 1 | saint george
# http://api.openweathermap.org/data/2.5/weather?q=saint%20george&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?q=mataura&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 1 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?q=cabo%20san%20lucas&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 1 | norman wells
# http://api.openweathermap.org/data/2.5/weather?q=norman%20wells&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 1 | ukiah
# http://api.openweathermap.org/data/2.5/weather?q=ukiah&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 1 | kapaa
# http://api.openweathermap.org/data/2.5/weather?q=kapaa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 1 | cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 1 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 1 | lindi
# http://api.openweathermap.org/data/2.5/weather?q=lindi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?q=tuatapere&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 1 | deputatskiy
# http://api.openweathermap.org/data/2.5/weather?q=deputatskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta%20arenas&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 1 | nuevo ideal
# http://api.openweathermap.org/data/2.5/weather?q=nuevo%20ideal&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 1 | cuenca
# http://api.openweathermap.org/data/2.5/weather?q=cuenca&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 1 | smithers
# http://api.openweathermap.org/data/2.5/weather?q=smithers&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 1 | nizhneyansk
# http://api.openweathermap.org/data/2.5/weather?q=nizhneyansk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 43 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?q=hilo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 1 | vila velha
# http://api.openweathermap.org/data/2.5/weather?q=vila%20velha&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 of Set 1 | avarua
# http://api.openweathermap.org/data/2.5/weather?q=avarua&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 1 | yumen
# http://api.openweathermap.org/data/2.5/weather?q=yumen&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 1 | trincomalee
# http://api.openweathermap.org/data/2.5/weather?q=trincomalee&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 48 of Set 1 | umzimvubu
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 49 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 1 | wanning
# http://api.openweathermap.org/data/2.5/weather?q=wanning&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 1 of Set 2 | tapes
# http://api.openweathermap.org/data/2.5/weather?q=tapes&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 2 | bar-le-duc
# http://api.openweathermap.org/data/2.5/weather?q=bar-le-duc&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 2 | collie
# http://api.openweathermap.org/data/2.5/weather?q=collie&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 2 | dolbeau
# http://api.openweathermap.org/data/2.5/weather?q=dolbeau&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 5 of Set 2 | lorengau
# http://api.openweathermap.org/data/2.5/weather?q=lorengau&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 2 | goianesia
# http://api.openweathermap.org/data/2.5/weather?q=goianesia&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 2 | kodiak
# http://api.openweathermap.org/data/2.5/weather?q=kodiak&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 2 | pochutla
# http://api.openweathermap.org/data/2.5/weather?q=pochutla&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 2 | salalah
# http://api.openweathermap.org/data/2.5/weather?q=salalah&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 2 | niquero
# http://api.openweathermap.org/data/2.5/weather?q=niquero&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 2 | upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 2 | auki
# http://api.openweathermap.org/data/2.5/weather?q=auki&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 2 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 2 | oussouye
# http://api.openweathermap.org/data/2.5/weather?q=oussouye&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 2 | guerrero negro
# http://api.openweathermap.org/data/2.5/weather?q=guerrero%20negro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 2 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 2 | tiarei
# http://api.openweathermap.org/data/2.5/weather?q=tiarei&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 2 | kisangani
# http://api.openweathermap.org/data/2.5/weather?q=kisangani&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 2 | ust-nera
# http://api.openweathermap.org/data/2.5/weather?q=ust-nera&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 2 | mentougou
# http://api.openweathermap.org/data/2.5/weather?q=mentougou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 2 | inhambane
# http://api.openweathermap.org/data/2.5/weather?q=inhambane&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 2 | kazalinsk
# http://api.openweathermap.org/data/2.5/weather?q=kazalinsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 23 of Set 2 | saucillo
# http://api.openweathermap.org/data/2.5/weather?q=saucillo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 2 | srisailam
# http://api.openweathermap.org/data/2.5/weather?q=srisailam&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?q=san%20patricio&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 2 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 27 of Set 2 | ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 2 | nishihara
# http://api.openweathermap.org/data/2.5/weather?q=nishihara&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 2 | esil
# http://api.openweathermap.org/data/2.5/weather?q=esil&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 2 | fatehpur
# http://api.openweathermap.org/data/2.5/weather?q=fatehpur&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 2 | calvinia
# http://api.openweathermap.org/data/2.5/weather?q=calvinia&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 2 | betanzos
# http://api.openweathermap.org/data/2.5/weather?q=betanzos&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 2 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 2 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san%20cristobal&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 2 | mount gambier
# http://api.openweathermap.org/data/2.5/weather?q=mount%20gambier&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 2 | tarakan
# http://api.openweathermap.org/data/2.5/weather?q=tarakan&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta%20do%20sol&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 2 | mongo
# http://api.openweathermap.org/data/2.5/weather?q=mongo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 2 | athabasca
# http://api.openweathermap.org/data/2.5/weather?q=athabasca&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 2 | luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 2 | george
# http://api.openweathermap.org/data/2.5/weather?q=george&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 2 | kondinskoye
# http://api.openweathermap.org/data/2.5/weather?q=kondinskoye&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 2 | batticaloa
# http://api.openweathermap.org/data/2.5/weather?q=batticaloa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 2 | sentyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=sentyabrskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 45 of Set 2 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?q=leningradskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 2 | evensk
# http://api.openweathermap.org/data/2.5/weather?q=evensk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 2 | talnakh
# http://api.openweathermap.org/data/2.5/weather?q=talnakh&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 48 of Set 2 | bilibino
# http://api.openweathermap.org/data/2.5/weather?q=bilibino&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 2 | saladoblanco
# http://api.openweathermap.org/data/2.5/weather?q=saladoblanco&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 2 | champerico
# http://api.openweathermap.org/data/2.5/weather?q=champerico&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 1 of Set 3 | dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 3 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?q=raudeberg&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 3 | codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 3 | tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 5 of Set 3 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?q=ribeira%20grande&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 3 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 3 | college
# http://api.openweathermap.org/data/2.5/weather?q=college&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 3 | bafra
# http://api.openweathermap.org/data/2.5/weather?q=bafra&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 9 of Set 3 | richards bay
# http://api.openweathermap.org/data/2.5/weather?q=richards%20bay&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 3 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?q=ostrovnoy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 3 | agadez
# http://api.openweathermap.org/data/2.5/weather?q=agadez&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 3 | tautira
# http://api.openweathermap.org/data/2.5/weather?q=tautira&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 3 | nantucket
# http://api.openweathermap.org/data/2.5/weather?q=nantucket&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 3 | dzerzhinsk
# http://api.openweathermap.org/data/2.5/weather?q=dzerzhinsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 3 | gweta
# http://api.openweathermap.org/data/2.5/weather?q=gweta&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 3 | butaritari
# http://api.openweathermap.org/data/2.5/weather?q=butaritari&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 3 | laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 3 | gigmoto
# http://api.openweathermap.org/data/2.5/weather?q=gigmoto&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 3 | vaitupu
# http://api.openweathermap.org/data/2.5/weather?q=vaitupu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 20 of Set 3 | dickinson
# http://api.openweathermap.org/data/2.5/weather?q=dickinson&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 3 | talaya
# http://api.openweathermap.org/data/2.5/weather?q=talaya&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 3 | puerto del rosario
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20del%20rosario&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 3 | devrek
# http://api.openweathermap.org/data/2.5/weather?q=devrek&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 3 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?q=turukhansk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 3 | nome
# http://api.openweathermap.org/data/2.5/weather?q=nome&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 3 | ketchikan
# http://api.openweathermap.org/data/2.5/weather?q=ketchikan&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 3 | itaituba
# http://api.openweathermap.org/data/2.5/weather?q=itaituba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 3 | dubovka
# http://api.openweathermap.org/data/2.5/weather?q=dubovka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 3 | tabou
# http://api.openweathermap.org/data/2.5/weather?q=tabou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 3 | santa josefa
# http://api.openweathermap.org/data/2.5/weather?q=santa%20josefa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 3 | teno
# http://api.openweathermap.org/data/2.5/weather?q=teno&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 3 | souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 3 | buchanan
# http://api.openweathermap.org/data/2.5/weather?q=buchanan&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 3 | gunjur
# http://api.openweathermap.org/data/2.5/weather?q=gunjur&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 3 | alyangula
# http://api.openweathermap.org/data/2.5/weather?q=alyangula&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 3 | kichera
# http://api.openweathermap.org/data/2.5/weather?q=kichera&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 3 | canakkale
# http://api.openweathermap.org/data/2.5/weather?q=canakkale&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 3 | weligama
# http://api.openweathermap.org/data/2.5/weather?q=weligama&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 3 | rawah
# http://api.openweathermap.org/data/2.5/weather?q=rawah&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 40 of Set 3 | sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 3 | lovozero
# http://api.openweathermap.org/data/2.5/weather?q=lovozero&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 3 | taoudenni
# http://api.openweathermap.org/data/2.5/weather?q=taoudenni&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 3 | koulikoro
# http://api.openweathermap.org/data/2.5/weather?q=koulikoro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 3 | satitoa
# http://api.openweathermap.org/data/2.5/weather?q=satitoa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 45 of Set 3 | vila
# http://api.openweathermap.org/data/2.5/weather?q=vila&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 3 | jiangyou
# http://api.openweathermap.org/data/2.5/weather?q=jiangyou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 3 | belushya guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya%20guba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 48 of Set 3 | yatou
# http://api.openweathermap.org/data/2.5/weather?q=yatou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 3 | kavieng
# http://api.openweathermap.org/data/2.5/weather?q=kavieng&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 3 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?q=mar%20del%20plata&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 1 of Set 4 | sangar
# http://api.openweathermap.org/data/2.5/weather?q=sangar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 4 | cartagena del chaira
# http://api.openweathermap.org/data/2.5/weather?q=cartagena%20del%20chaira&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 4 | castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 4 | chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 4 | lenine
# http://api.openweathermap.org/data/2.5/weather?q=lenine&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 4 | topsham
# http://api.openweathermap.org/data/2.5/weather?q=topsham&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 4 | presidencia roque saenz pena
# http://api.openweathermap.org/data/2.5/weather?q=presidencia%20roque%20saenz%20pena&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 4 | taltal
# http://api.openweathermap.org/data/2.5/weather?q=taltal&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 4 | axim
# http://api.openweathermap.org/data/2.5/weather?q=axim&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 4 | marshall
# http://api.openweathermap.org/data/2.5/weather?q=marshall&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 4 | east london
# http://api.openweathermap.org/data/2.5/weather?q=east%20london&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 4 | marcona
# http://api.openweathermap.org/data/2.5/weather?q=marcona&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 13 of Set 4 | port macquarie
# http://api.openweathermap.org/data/2.5/weather?q=port%20macquarie&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 4 | provideniya
# http://api.openweathermap.org/data/2.5/weather?q=provideniya&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 4 | batemans bay
# http://api.openweathermap.org/data/2.5/weather?q=batemans%20bay&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 4 | hihifo
# http://api.openweathermap.org/data/2.5/weather?q=hihifo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 17 of Set 4 | tiksi
# http://api.openweathermap.org/data/2.5/weather?q=tiksi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 4 | athens
# http://api.openweathermap.org/data/2.5/weather?q=athens&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 4 | khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 4 | angouleme
# http://api.openweathermap.org/data/2.5/weather?q=angouleme&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 4 | sikasso
# http://api.openweathermap.org/data/2.5/weather?q=sikasso&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 4 | inuvik
# http://api.openweathermap.org/data/2.5/weather?q=inuvik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 4 | hualmay
# http://api.openweathermap.org/data/2.5/weather?q=hualmay&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 4 | pemangkat
# http://api.openweathermap.org/data/2.5/weather?q=pemangkat&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 25 of Set 4 | kamenka
# http://api.openweathermap.org/data/2.5/weather?q=kamenka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 4 | smolenka
# http://api.openweathermap.org/data/2.5/weather?q=smolenka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 4 | fujin
# http://api.openweathermap.org/data/2.5/weather?q=fujin&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 4 | lagoa
# http://api.openweathermap.org/data/2.5/weather?q=lagoa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 4 | nouadhibou
# http://api.openweathermap.org/data/2.5/weather?q=nouadhibou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 4 | saint-pierre
# http://api.openweathermap.org/data/2.5/weather?q=saint-pierre&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 4 | kenai
# http://api.openweathermap.org/data/2.5/weather?q=kenai&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 4 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?q=bambanglipuro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 4 | kirzhach
# http://api.openweathermap.org/data/2.5/weather?q=kirzhach&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 4 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?q=severo-kurilsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 4 | lazaro cardenas
# http://api.openweathermap.org/data/2.5/weather?q=lazaro%20cardenas&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 4 | harper
# http://api.openweathermap.org/data/2.5/weather?q=harper&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 4 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port%20elizabeth&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 4 | wahiawa
# http://api.openweathermap.org/data/2.5/weather?q=wahiawa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 4 | petropavlovsk-kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?q=petropavlovsk-kamchatskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 4 | qui nhon
# http://api.openweathermap.org/data/2.5/weather?q=qui%20nhon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 41 of Set 4 | nogliki
# http://api.openweathermap.org/data/2.5/weather?q=nogliki&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 4 | cagayan de tawi-tawi
# http://api.openweathermap.org/data/2.5/weather?q=cagayan%20de%20tawi-tawi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 43 of Set 4 | guane
# http://api.openweathermap.org/data/2.5/weather?q=guane&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 4 | katsuura
# http://api.openweathermap.org/data/2.5/weather?q=katsuura&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 of Set 4 | adrar
# http://api.openweathermap.org/data/2.5/weather?q=adrar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 4 | atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 4 | touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 48 of Set 4 | sitka
# http://api.openweathermap.org/data/2.5/weather?q=sitka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 4 | enshi
# http://api.openweathermap.org/data/2.5/weather?q=enshi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 4 | aran
# http://api.openweathermap.org/data/2.5/weather?q=aran&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 1 of Set 5 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?q=tuktoyaktuk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 5 | tostamaa
# http://api.openweathermap.org/data/2.5/weather?q=tostamaa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 3 of Set 5 | severnoye
# http://api.openweathermap.org/data/2.5/weather?q=severnoye&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 5 | puerto escondido
# http://api.openweathermap.org/data/2.5/weather?q=puerto%20escondido&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 5 | prince rupert
# http://api.openweathermap.org/data/2.5/weather?q=prince%20rupert&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 5 | umba
# http://api.openweathermap.org/data/2.5/weather?q=umba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 5 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?q=olafsvik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 8 of Set 5 | cilegon
# http://api.openweathermap.org/data/2.5/weather?q=cilegon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 5 | oranjemund
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 5 | clyde river
# http://api.openweathermap.org/data/2.5/weather?q=clyde%20river&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 5 | vanavara
# http://api.openweathermap.org/data/2.5/weather?q=vanavara&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 5 | hobyo
# http://api.openweathermap.org/data/2.5/weather?q=hobyo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 5 | ritchie
# http://api.openweathermap.org/data/2.5/weather?q=ritchie&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 5 | luanda
# http://api.openweathermap.org/data/2.5/weather?q=luanda&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 5 | stoyba
# http://api.openweathermap.org/data/2.5/weather?q=stoyba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 16 of Set 5 | naze
# http://api.openweathermap.org/data/2.5/weather?q=naze&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 5 | attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 18 of Set 5 | sovetskiy
# http://api.openweathermap.org/data/2.5/weather?q=sovetskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 5 | zhigansk
# http://api.openweathermap.org/data/2.5/weather?q=zhigansk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 5 | yoichi
# http://api.openweathermap.org/data/2.5/weather?q=yoichi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 5 | burgeo
# http://api.openweathermap.org/data/2.5/weather?q=burgeo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 5 | jacala
# http://api.openweathermap.org/data/2.5/weather?q=jacala&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 5 | sao filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao%20filipe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 5 | erenhot
# http://api.openweathermap.org/data/2.5/weather?q=erenhot&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 5 | mys shmidta
# http://api.openweathermap.org/data/2.5/weather?q=mys%20shmidta&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 26 of Set 5 | aykhal
# http://api.openweathermap.org/data/2.5/weather?q=aykhal&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 5 | kupang
# http://api.openweathermap.org/data/2.5/weather?q=kupang&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 5 | flin flon
# http://api.openweathermap.org/data/2.5/weather?q=flin%20flon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 5 | wazzan
# http://api.openweathermap.org/data/2.5/weather?q=wazzan&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 30 of Set 5 | vao
# http://api.openweathermap.org/data/2.5/weather?q=vao&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 5 | avanigadda
# http://api.openweathermap.org/data/2.5/weather?q=avanigadda&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 5 | nalut
# http://api.openweathermap.org/data/2.5/weather?q=nalut&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 5 | rincon
# http://api.openweathermap.org/data/2.5/weather?q=rincon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 5 | talawdi
# http://api.openweathermap.org/data/2.5/weather?q=talawdi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 35 of Set 5 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 5 | tynda
# http://api.openweathermap.org/data/2.5/weather?q=tynda&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 5 | qazvin
# http://api.openweathermap.org/data/2.5/weather?q=qazvin&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 5 | neftcala
# http://api.openweathermap.org/data/2.5/weather?q=neftcala&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 5 | porbandar
# http://api.openweathermap.org/data/2.5/weather?q=porbandar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 5 | sampit
# http://api.openweathermap.org/data/2.5/weather?q=sampit&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 5 | misratah
# http://api.openweathermap.org/data/2.5/weather?q=misratah&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 5 | hay river
# http://api.openweathermap.org/data/2.5/weather?q=hay%20river&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 5 | beringovskiy
# http://api.openweathermap.org/data/2.5/weather?q=beringovskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 5 | constitucion
# ...
# Processing Record 49 of Set 9 | braganca
# http://api.openweathermap.org/data/2.5/weather?q=braganca&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 9 | tarudant
# http://api.openweathermap.org/data/2.5/weather?q=tarudant&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 1 of Set 10 | husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 10 | duminichi
# http://api.openweathermap.org/data/2.5/weather?q=duminichi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 10 | te anau
# http://api.openweathermap.org/data/2.5/weather?q=te%20anau&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 10 | barnstaple
# http://api.openweathermap.org/data/2.5/weather?q=barnstaple&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 10 | general pico
# http://api.openweathermap.org/data/2.5/weather?q=general%20pico&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 10 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 10 | lethem
# http://api.openweathermap.org/data/2.5/weather?q=lethem&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 10 | ayan
# http://api.openweathermap.org/data/2.5/weather?q=ayan&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 10 | manta
# http://api.openweathermap.org/data/2.5/weather?q=manta&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 10 | kimbe
# http://api.openweathermap.org/data/2.5/weather?q=kimbe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 10 | leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?q=leshukonskoye&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 10 | paita
# http://api.openweathermap.org/data/2.5/weather?q=paita&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 13 of Set 10 | udachnyy
# http://api.openweathermap.org/data/2.5/weather?q=udachnyy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 10 | matamoros
# http://api.openweathermap.org/data/2.5/weather?q=matamoros&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 10 | belle glade
# http://api.openweathermap.org/data/2.5/weather?q=belle%20glade&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 16 of Set 10 | hofn
# http://api.openweathermap.org/data/2.5/weather?q=hofn&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 10 | pangody
# http://api.openweathermap.org/data/2.5/weather?q=pangody&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 10 | sterling
# http://api.openweathermap.org/data/2.5/weather?q=sterling&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 10 | nagapattinam
# http://api.openweathermap.org/data/2.5/weather?q=nagapattinam&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 10 | parabel
# http://api.openweathermap.org/data/2.5/weather?q=parabel&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 10 | kracheh
# http://api.openweathermap.org/data/2.5/weather?q=kracheh&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 22 of Set 10 | oktyabrskiy
# http://api.openweathermap.org/data/2.5/weather?q=oktyabrskiy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 10 | wilmington island
# http://api.openweathermap.org/data/2.5/weather?q=wilmington%20island&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 10 | manokwari
# http://api.openweathermap.org/data/2.5/weather?q=manokwari&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 25 of Set 10 | ruiz
# http://api.openweathermap.org/data/2.5/weather?q=ruiz&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 10 | imbituba
# http://api.openweathermap.org/data/2.5/weather?q=imbituba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 10 | daru
# http://api.openweathermap.org/data/2.5/weather?q=daru&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 10 | sabinov
# http://api.openweathermap.org/data/2.5/weather?q=sabinov&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 10 | alihe
# http://api.openweathermap.org/data/2.5/weather?q=alihe&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 10 | benguela
# http://api.openweathermap.org/data/2.5/weather?q=benguela&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 10 | saint-augustin
# http://api.openweathermap.org/data/2.5/weather?q=saint-augustin&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 10 | marzuq
# http://api.openweathermap.org/data/2.5/weather?q=marzuq&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 10 | borba
# http://api.openweathermap.org/data/2.5/weather?q=borba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 10 | sao joao da barra
# http://api.openweathermap.org/data/2.5/weather?q=sao%20joao%20da%20barra&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 10 | katakwi
# http://api.openweathermap.org/data/2.5/weather?q=katakwi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 10 | mookane
# http://api.openweathermap.org/data/2.5/weather?q=mookane&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 10 | heze
# http://api.openweathermap.org/data/2.5/weather?q=heze&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 10 | xiongzhou
# http://api.openweathermap.org/data/2.5/weather?q=xiongzhou&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 10 | cheltenham
# http://api.openweathermap.org/data/2.5/weather?q=cheltenham&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 10 | sechura
# http://api.openweathermap.org/data/2.5/weather?q=sechura&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 10 | manggar
# http://api.openweathermap.org/data/2.5/weather?q=manggar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 10 | homer
# http://api.openweathermap.org/data/2.5/weather?q=homer&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 10 | shingu
# http://api.openweathermap.org/data/2.5/weather?q=shingu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 10 | shubarshi
# http://api.openweathermap.org/data/2.5/weather?q=shubarshi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 of Set 10 | broome
# http://api.openweathermap.org/data/2.5/weather?q=broome&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 10 | road town
# http://api.openweathermap.org/data/2.5/weather?q=road%20town&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 10 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?q=ciudad%20bolivar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 48 of Set 10 | aksu
# http://api.openweathermap.org/data/2.5/weather?q=aksu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 10 | roald
# http://api.openweathermap.org/data/2.5/weather?q=roald&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 10 | tingrela
# http://api.openweathermap.org/data/2.5/weather?q=tingrela&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 1 of Set 11 | klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 2 of Set 11 | kalulushi
# http://api.openweathermap.org/data/2.5/weather?q=kalulushi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 3 of Set 11 | rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 4 of Set 11 | oxapampa
# http://api.openweathermap.org/data/2.5/weather?q=oxapampa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 5 of Set 11 | kawalu
# http://api.openweathermap.org/data/2.5/weather?q=kawalu&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 6 of Set 11 | chipinge
# http://api.openweathermap.org/data/2.5/weather?q=chipinge&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 7 of Set 11 | marathon
# http://api.openweathermap.org/data/2.5/weather?q=marathon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 8 of Set 11 | sabha
# http://api.openweathermap.org/data/2.5/weather?q=sabha&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 9 of Set 11 | general roca
# http://api.openweathermap.org/data/2.5/weather?q=general%20roca&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 10 of Set 11 | zirandaro
# http://api.openweathermap.org/data/2.5/weather?q=zirandaro&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 11 of Set 11 | muncar
# http://api.openweathermap.org/data/2.5/weather?q=muncar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 12 of Set 11 | brasileia
# http://api.openweathermap.org/data/2.5/weather?q=brasileia&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 13 of Set 11 | noyabrsk
# http://api.openweathermap.org/data/2.5/weather?q=noyabrsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 14 of Set 11 | kuusamo
# http://api.openweathermap.org/data/2.5/weather?q=kuusamo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 15 of Set 11 | zolotinka
# http://api.openweathermap.org/data/2.5/weather?q=zolotinka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 16 of Set 11 | nahrin
# http://api.openweathermap.org/data/2.5/weather?q=nahrin&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 17 of Set 11 | belyy yar
# http://api.openweathermap.org/data/2.5/weather?q=belyy%20yar&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 18 of Set 11 | lyuban
# http://api.openweathermap.org/data/2.5/weather?q=lyuban&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 19 of Set 11 | kologriv
# http://api.openweathermap.org/data/2.5/weather?q=kologriv&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 20 of Set 11 | dudinka
# http://api.openweathermap.org/data/2.5/weather?q=dudinka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 21 of Set 11 | amapa
# http://api.openweathermap.org/data/2.5/weather?q=amapa&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 22 of Set 11 | san ramon
# http://api.openweathermap.org/data/2.5/weather?q=san%20ramon&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 23 of Set 11 | oskemen
# http://api.openweathermap.org/data/2.5/weather?q=oskemen&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 24 of Set 11 | falealupo
# http://api.openweathermap.org/data/2.5/weather?q=falealupo&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 25 of Set 11 | bam
# http://api.openweathermap.org/data/2.5/weather?q=bam&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 26 of Set 11 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?q=port%20lincoln&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 27 of Set 11 | knysna
# http://api.openweathermap.org/data/2.5/weather?q=knysna&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 28 of Set 11 | cedar city
# http://api.openweathermap.org/data/2.5/weather?q=cedar%20city&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 29 of Set 11 | tarija
# http://api.openweathermap.org/data/2.5/weather?q=tarija&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 30 of Set 11 | pszczyna
# http://api.openweathermap.org/data/2.5/weather?q=pszczyna&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 31 of Set 11 | shelburne
# http://api.openweathermap.org/data/2.5/weather?q=shelburne&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 32 of Set 11 | chulym
# http://api.openweathermap.org/data/2.5/weather?q=chulym&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 33 of Set 11 | skjervoy
# http://api.openweathermap.org/data/2.5/weather?q=skjervoy&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 34 of Set 11 | aksarka
# http://api.openweathermap.org/data/2.5/weather?q=aksarka&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 35 of Set 11 | sosnogorsk
# http://api.openweathermap.org/data/2.5/weather?q=sosnogorsk&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 36 of Set 11 | whyalla
# http://api.openweathermap.org/data/2.5/weather?q=whyalla&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 37 of Set 11 | buraydah
# http://api.openweathermap.org/data/2.5/weather?q=buraydah&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 38 of Set 11 | gisborne
# http://api.openweathermap.org/data/2.5/weather?q=gisborne&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 39 of Set 11 | skegness
# http://api.openweathermap.org/data/2.5/weather?q=skegness&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 40 of Set 11 | xiongyue
# http://api.openweathermap.org/data/2.5/weather?q=xiongyue&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 41 of Set 11 | show low
# http://api.openweathermap.org/data/2.5/weather?q=show%20low&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 42 of Set 11 | mocuba
# http://api.openweathermap.org/data/2.5/weather?q=mocuba&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 43 of Set 11 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 44 of Set 11 | chingirlau
# http://api.openweathermap.org/data/2.5/weather?q=chingirlau&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 45 of Set 11 | port blair
# http://api.openweathermap.org/data/2.5/weather?q=port%20blair&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 46 of Set 11 | inirida
# http://api.openweathermap.org/data/2.5/weather?q=inirida&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 47 of Set 11 | parainen
# http://api.openweathermap.org/data/2.5/weather?q=parainen&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# HTTP Error 404: Not Found
# Processing Record 48 of Set 11 | takoradi
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 49 of Set 11 | sola
# http://api.openweathermap.org/data/2.5/weather?q=sola&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# Processing Record 50 of Set 11 | san lawrenz
# http://api.openweathermap.org/data/2.5/weather?q=san%20lawrenz&units=imperial&APPID=25bc90a1196e6f153eece0bc0b0fc9eb
# end of stats loop
# Could not get data for 61 cities

# %%
# Display the count of cities with weather data
WeatherPy_df.count()
# Out:
# City          539
# Cloudiness    539
# Country       539
# Date          539
# Max Temp      539
# Wind Speed    539
# Lat           539
# Lng           539
# Humidity      539
# dtype: int64

# %%
# save to csv file
WeatherPy_df.to_csv("WeatherPy.csv", encoding='utf-8', index=False)

# Display the city weather data frame
WeatherPy_df.head(10)
# Out:
#           City Cloudiness Country        Date Max Temp Wind Speed    Lat  \
# 0    Cape Town          0      ZA  1529550000     42.8        4.7 -33.93
# 1       Najran         20      SA  1529550000     78.8       3.85  17.54
# 2        Fukue         75      JP  1529548200     73.4      10.29  35.03
# 3    Busselton         92      AU  1529551322    62.19      11.56 -33.64
# 4        Bluff         36      AU  1529551664    69.57       8.77 -23.58
# 5    Ilulissat          0      GL  1529549400     48.2      17.22  69.22
# 6  Port Alfred          0      ZA  1529551383     60.3       9.89 -33.59
# 7       Hobart         20      AU  1529548200     53.6      12.75 -42.88
# 8      Kahului         40      US  1529549760     84.2      18.34  20.89
# 9      Rikitea         32      PF  1529551379     73.8       6.98 -23.12
#
#       Lng Humidity
# 0   18.42       93
# 1   44.22       19
# 2  136.69       83
# 3  115.35      100
# 4  149.07       48
# 5   -51.1       45
# 6   26.89       96
# 7  147.33       50
# 8 -156.47       62
# 9 -134.97      100

# %%
plt.figure(figsize=(10,8))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Max Temp"], color='r', alpha=0.5)
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.title(f'City Latitude vs Max Temperature ({datetime.now().date()})')
plt.savefig("LatVsTemp.png")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Humidity"], color='blue', alpha=0.5)
plt.ylim(10,120)
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.title(f'City Latitude vs Humidity ({datetime.now().date()})')
plt.savefig("LatVsHumidity.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Cloudiness"], color='green', alpha=0.5)

plt.ylim(-20,(WeatherPy_df["Cloudiness"].max()+10))
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.title(f'City Latitude vs Cloudiness ({datetime.now().date()})')
plt.savefig("LatVsCloudiness.png")
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.set()
plt.scatter(WeatherPy_df["Lat"], WeatherPy_df["Wind Speed"], color='orange', alpha=0.5)

plt.ylim((WeatherPy_df["Wind Speed"].min()-5),(WeatherPy_df["Wind Speed"].max()+5))
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.title(f'City Latitude vs Wind Speed ({datetime.now().date()})')
plt.savefig("LatVsWind.png")
plt.show()
